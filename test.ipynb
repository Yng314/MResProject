# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'd:\\workspace\\MRes'

# %%
df = pd.read_csv("datasets\mimic-cxr-jpg-2.1.0\mimic-cxr-2.0.0-metadata.csv.gz")

# %%
result = df[df['dicom_id'] == '687754ce-7420bfd3-0a19911f-a27a3916-9019cd53']
result
# Out:
#                                           dicom_id  subject_id  study_id  \
# 1461  687754ce-7420bfd3-0a19911f-a27a3916-9019cd53    10032725  50331901
#
#      PerformedProcedureStepDescription ViewPosition  Rows  Columns  StudyDate  \
# 1461               CHEST (PORTABLE AP)          NaN  2140     1760   21430322
#
#       StudyTime ProcedureCodeSequence_CodeMeaning  \
# 1461   101701.0               CHEST (PORTABLE AP)
#
#      ViewCodeSequence_CodeMeaning PatientOrientationCodeSequence_CodeMeaning
# 1461                          NaN                                        NaN

# %%
df.loc[df['ViewPosition'].isna()]
# Out:
#                                             dicom_id  subject_id  study_id  \
# 44      8039752c-2ea661b7-16f1eafe-055b7e7b-dbd4cdd1    10001122  53447138
# 45      832b57d8-3ae08663-e152699e-51c5db98-b7cb4226    10001122  53447138
# 130     227844e4-4cf4b717-bb4bf0e5-961883ef-664990fe    10002013  55312734
# 131     66ccec51-f0d48809-dc6f7ba3-68acf728-a1514edf    10002013  55312734
# 145     8b88f03a-2004113d-4118def5-35820db5-d0913df8    10002221  53781756
# ...                                              ...         ...       ...
# 377085  458b41b5-6c8bfc44-a4dff92c-254519d0-9c40e805    19999068  59937395
# 377088  9c44a9e5-7a8fcfa1-cb6b451f-1d1ac993-5312b1c2    19999270  55274188
# 377089  f5cbd087-0490844c-4e1d38f7-154dc31a-4e99dbd1    19999270  55274188
# 377090  bf6e3bdb-4ec92b48-340d4e48-7a00234a-1b76dae7    19999270  56267753
# 377091  f83a9135-334e26ff-6419b6b9-1457634a-aaed76a3    19999270  56267753
#
# ...

# %%
(df['ViewPosition']=='LATERAL').mean()+df['ViewPosition'].isna().mean()
# Out:
# 0.26152051125666254

# %%
(df['ViewPosition']=='PA').mean()+(df['ViewPosition']=='AP').mean()+(df['ViewPosition']=='AP AXIAL').mean()
# Out:
# 0.6452653072047944

# %%
gt = pd.read_csv("./datasets/mimic-cxr-clean/gt/metadata.csv")

# %%
(gt['ViewPosition']=='AP').mean()+(gt['ViewPosition']=='PA').mean()
# Out:
# 0.6569484936831875

# %%
(gt['ViewPosition'].isna()).mean()+(gt['ViewPosition']=='LATERAL').mean()
# Out:
# 0.22546161321671526

# %%
df['ViewPosition'].unique()
# Out:
# array(['PA', 'LATERAL', 'AP', 'LL', nan, 'LAO', 'RAO', 'AP AXIAL',
#        'SWIMMERS', 'PA LLD', 'AP LLD', 'XTABLE LATERAL', 'AP RLD',
#        'PA RLD', 'LPO'], dtype=object)
